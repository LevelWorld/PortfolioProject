# %%
# First let's import the packages we will use in this project
# You can do this all now or as you need them
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# read in the data
df = pd.read_csv(r"D:\career\Downloads\movies.csv\movies.csv")

# %%
# looking at the data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#     released date       location  score      votes         director  \
# 0  June 13, 1980   United States    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980   United States    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980   United States    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980   United States    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980   United States    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# finding missing data

col_to_edit = []
for col in df.columns:
    pct_missing =np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
    if pct_missing > 0:
        col_to_edit.append(col)
for col in col_to_edit:
    df[col].fillna(0, inplace = True)
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released date - 0.0%
# location - 0.0%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# data types for the columns
#df.dtypes
type(df['released date'])
# Out:
# pandas.core.series.Series

# %%
# coverting data type
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
# rectify in consistencies with the data by createing a new column
df['year_corrected'] = (df['released date'].astype(str).str[-5:])

# %%
df = df.sort_values(by=['gross'], inplace=False, ascending=False)

# %%
# Drop any duplicates
df.drop_duplicates()
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century      0   Comedy  1989
# 7667                                   Tee em el      0   Horror  2020
#
#            released date       location  score      votes        director  \
# ...

# %%
# Scatter plot with budget vs gross

plt.scatter(x=df['budget'],y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#            released date       location  score      votes       director  \
# 5445  December 18, 2009   United States    7.8  1100000.0  James Cameron
# 7445     April 26, 2019   United States    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997   United States    7.8  1100000.0  James Cameron
# 6663  December 18, 2015   United States    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018   United States    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# Plot Buget vs Gross using seaborn
sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"} )
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
# calcuclating correlation
correlation_matrix = df.corr(numeric_only =True, method='pearson') # can also use kendall, spearman
sns.heatmap(correlation_matrix, annot=True)
plt.title('correlation matrix')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
#looking at companies
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#            released date       location  score      votes       director  \
# 5445  December 18, 2009   United States    7.8  1100000.0  James Cameron
# 7445     April 26, 2019   United States    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997   United States    7.8  1100000.0  James Cameron
# 6663  December 18, 2015   United States    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018   United States    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
df_numerized = df

for col_name in df_numerized.columns:
    if (df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
df_numerized.head()
# Out:
#       name  rating  genre  year  released date  location  score      votes  \
# 5445   533       6      0  2009            611        57    7.8  1100000.0
# 7445   535       6      0  2019            154        57    8.4   903000.0
# 3045  6896       6      6  1997            617        57    7.8  1100000.0
# 6663  5144       6      0  2015            613        57    7.8   876000.0
# 7244   536       6      0  2018            162        57    8.4   897000.0
#
#       director  writer  star  country     budget       gross  company  \
# 5445      1155    1779  2335       56  237000000  2847246203     2254
# 7445       162     744  2242       56  356000000  2797501328     1607
# 3045      1155    1779  1596       56  200000000  2201647264     2254
# 6663      1125    2551   525       56  245000000  2069521700     1541
# 7244       162     744  2242       56  321000000  2048359754     1607
#
#       runtime  year_corrected
# 5445    162.0              29
# 7445    181.0              39
# ...

# %%
# calcuclating correlation
correlation_matrix = df_numerized.corr(numeric_only =True, method='pearson') # can also use kendall, spearman
sns.heatmap(correlation_matrix, annot=False)
plt.title('correlation matrix')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
correlation_matrix = df_numerized.corr()
corr_pairs = correlation_matrix.unstack()
corr_pairs
# Out:
# name            name              1.000000
#                 rating           -0.008069
#                 genre             0.016355
#                 year              0.011453
#                 released date    -0.011223
#                                     ...
# year_corrected  budget            0.299603
#                 gross             0.254686
#                 company          -0.016109
#                 runtime           0.114737
#                 year_corrected    1.000000
# Length: 289, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# budget          genre            -0.334021
# genre           budget           -0.334021
#                 gross            -0.234297
# gross           genre            -0.234297
# genre           votes            -0.145296
#                                     ...
# year            year              1.000000
# genre           genre             1.000000
# rating          rating            1.000000
# runtime         runtime           1.000000
# year_corrected  year_corrected    1.000000
# Length: 289, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# gross           votes             0.632870
# votes           gross             0.632870
# budget          gross             0.750157
# gross           budget            0.750157
# year            year_corrected    0.997295
# year_corrected  year              0.997295
# name            name              1.000000
# director        director          1.000000
# company         company           1.000000
# gross           gross             1.000000
# budget          budget            1.000000
# country         country           1.000000
# star            star              1.000000
# writer          writer            1.000000
# votes           votes             1.000000
# score           score             1.000000
# location        location          1.000000
# released date   released date     1.000000
# year            year              1.000000
# genre           genre             1.000000
# rating          rating            1.000000
# runtime         runtime           1.000000
# ...

# %%
# budget and votes have the highest correlation to gross earnings
# company has a low correlation.
